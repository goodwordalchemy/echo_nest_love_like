# %% [markdown]
# **Bigger Goal** is to distinguish between songs that I merely *like* and songs that I *love*
#
# ###Loading the data

# %%
import requests
import json
import spotipy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline
import sys


import playlist_data

# %%
USERNAME = 'dbgoldberg01'
favorites = playlist_data.main(USERNAME, 'science')
favorites.head()
# Out:
# Setting up
# getting playlist tracks from spotify
# merge with track and artist info from echo nest
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# error getting track artist data for  None
# 70
# 80
# 90
# 0
# error on uri spotify:track:76GGyeUiOtzsZjCxIJGDpd index= 1
# error on uri spotify:track:6XPC7ZNTJcnWzQaLZYe3od index= 3
# error on uri spotify:track:5KFdwLvJ0Bokm0TFlSPq47 index= 8
# 10
# error on uri spotify:track:4llDF3RuBQYj2nkjTCJY4w index= 14
# error on uri spotify:track:4Ddaf5bxzGfW1Ut2UtpTUl index= 20
# 20
# error on uri spotify:track:7c13Xlndg43PnSzpHRD11d index= 21
# error on uri spotify:track:63fKR9muo3uUwlFwlwZLG1 index= 25
# error on uri spotify:track:70MwBHOWTqublM7K5kjH0f index= 26
# error on uri spotify:track:70MwBHOWTqublM7K5kjH0f index= 27
# error on uri spotify:track:70MwBHOWTqublM7K5kjH0f index= 28
# error on uri spotify:track:69CKj4XCzIY89pYoiAaHwP index= 29
# error on uri spotify:track:69CKj4XCzIY89pYoiAaHwP index= 30
# 30
# error on uri spotify:track:69CKj4XCzIY89pYoiAaHwP index= 31
# error on uri spotify:track:57V3qFWPxsUB3PTFQbWyDk index= 32
# error on uri spotify:track:49HEwdXGHQkcApPc9YzdXZ index= 33
# error on uri spotify:track:49HEwdXGHQkcApPc9YzdXZ index= 34
# error on uri spotify:track:1d1uRlSEcYFmty6ihoAr84 index= 35
# error on uri spotify:track:1d1uRlSEcYFmty6ihoAr84 index= 36
# error on uri spotify:track:63vL5oxWrlvaJ0ayNaQnbX index= 39
# 40
# error on uri spotify:track:3AEBanY12LrfnintiDqZ3f index= 44
# error on uri spotify:track:3AEBanY12LrfnintiDqZ3f index= 45
# error on uri spotify:track:3Y5N6bX69lWiUCbiz8pnvm index= 48
# error on uri spotify:track:0byUGapJ70OOpxIC3U1jlf index= 50
# 50
# error on uri spotify:track:0byUGapJ70OOpxIC3U1jlf index= 51
# error on uri spotify:track:6CqIyOHZqc7oPdSQcZYZbE index= 52
# error on uri spotify:track:6CqIyOHZqc7oPdSQcZYZbE index= 53
# error on uri spotify:track:6CqIyOHZqc7oPdSQcZYZbE index= 54
# error on uri spotify:track:60YOZLX27AeCCyiDyTQE9K index= 55
# error on uri spotify:track:60YOZLX27AeCCyiDyTQE9K index= 56
# error on uri spotify:track:60YOZLX27AeCCyiDyTQE9K index= 57
# 60
# error on uri spotify:track:5gZE3gjRCk7JFkmw8n1DLf index= 68
# error on uri spotify:track:5gZE3gjRCk7JFkmw8n1DLf index= 69
# error on uri spotify:track:5gZE3gjRCk7JFkmw8n1DLf index= 70
# 70
# error on uri spotify:track:5gZE3gjRCk7JFkmw8n1DLf index= 71
# error on uri spotify:track:5gZE3gjRCk7JFkmw8n1DLf index= 72
# error on uri spotify:track:733kKdTUZ3FjNu4l1vb6z7 index= 73
# error on uri spotify:track:733kKdTUZ3FjNu4l1vb6z7 index= 74
# error on uri spotify:track:733kKdTUZ3FjNu4l1vb6z7 index= 75
# error on uri spotify:track:733kKdTUZ3FjNu4l1vb6z7 index= 76
# error on uri spotify:track:733kKdTUZ3FjNu4l1vb6z7 index= 77
# 80
# error on uri spotify:track:4YkgNzgT9tSYq1banrVIAh index= 83
# error on uri spotify:track:4YkgNzgT9tSYq1banrVIAh index= 84
# error on uri spotify:track:4YkgNzgT9tSYq1banrVIAh index= 85
# error on uri spotify:track:4YkgNzgT9tSYq1banrVIAh index= 86
# error on uri spotify:track:4YkgNzgT9tSYq1banrVIAh index= 87
# 90
# error on uri spotify:track:3uuSPJSUhrKqQI9OZKZppk index= 93
# error on uri spotify:track:4XYXstQNZUka3SFt2tMRXm index= 97
# error on uri spotify:track:4XYXstQNZUka3SFt2tMRXm index= 98
# error on uri spotify:track:1Tv9qSnAG0OHQQkV4GL35W index= 99
# error on uri spotify:track:1Tv9qSnAG0OHQQkV4GL35W index= 100
# 100
# error on uri spotify:track:3N6ctbfyJQkafosZVyyGTR index= 101
# error on uri spotify:track:565VhGSL1XAqeygegzsYHP index= 102
# error on uri spotify:track:6o2hYiisaM3hA8KW2XeB14 index= 103
# error on uri spotify:track:6iwOSeM2WzrKXFcSZL9VwY index= 104
# error on uri spotify:track:7xKdGKe93MKH0aOAV6jHn2 index= 105
# 110
# error on uri spotify:track:78D6sK7lXgcZEbQEPCi1Aw index= 112
# error on uri spotify:track:78D6sK7lXgcZEbQEPCi1Aw index= 113
# error on uri spotify:track:78D6sK7lXgcZEbQEPCi1Aw index= 114
# 120
# error on uri spotify:track:6ALsYBnSDRt3iFW9uzSJCR index= 121
# error on uri spotify:track:4OMu5a8sFpcRCPCcsoEaov index= 122
# error on uri spotify:track:4OMu5a8sFpcRCPCcsoEaov index= 123
# error on uri spotify:track:4OMu5a8sFpcRCPCcsoEaov index= 124
# error on uri spotify:track:31JPQ2tHR7fpyRzwIsF7tT index= 125
# error on uri spotify:track:31JPQ2tHR7fpyRzwIsF7tT index= 126
# error on uri spotify:track:31JPQ2tHR7fpyRzwIsF7tT index= 127
# 130
# error on uri spotify:track:5BtbRb1XfakaECaQoa0AOo index= 137
# 140
# error on uri spotify:track:6fOh11kHHoQiwSNA5ybRA9 index= 141
# error on uri spotify:track:5veFQvY6ooJ0rzjxO9cAkW index= 143
# error on uri spotify:track:5ZGBFimObEVokm5WcSjScd index= 145
# error on uri spotify:track:5bmckclk6SarpAS5cIepKT index= 147
# error on uri spotify:track:54sYjbTgO1tep1u24QMUyR index= 148
# error on uri spotify:track:4ST0Z3runlIMNH7L0BosGG index= 149
# error on uri spotify:track:3SAEZzDy9hOiJJXRuC58tN index= 150
# 150
# error on uri spotify:track:3zpYNsqxuinSybpTykdYCH index= 152
# error on uri spotify:track:41WEwKylrdXcrK3ksfDlv5 index= 153
# 160
# error on uri spotify:track:4sbugcdivw4TQKxLE4V5lS index= 163
# error on uri spotify:track:4sbugcdivw4TQKxLE4V5lS index= 164
# error on uri spotify:track:3mSgEsdhco8LaN0gGsS14o index= 165
# error on uri spotify:track:3mSgEsdhco8LaN0gGsS14o index= 166
# error on uri spotify:track:3iF1dglV6BinTBCXWKRvHx index= 169
# 170
#          track_name                track_id  \
# 0         Graceland  3lbRocWWpBVO9eefdjGi60
# 1          Speak In  76GGyeUiOtzsZjCxIJGDpd
# 2       The Funeral  4o0NjemqhmsYLIMwlcosvW
# 3       Open Season  6XPC7ZNTJcnWzQaLZYe3od
# 4  Artificial Light  2Y93hToFlR6CBItrUqsGqG
#
#                               track_uri  track_popularity  \
# 0  spotify:track:3lbRocWWpBVO9eefdjGi60                12
# 1  spotify:track:76GGyeUiOtzsZjCxIJGDpd                 0
# 2  spotify:track:4o0NjemqhmsYLIMwlcosvW                76
# 3  spotify:track:6XPC7ZNTJcnWzQaLZYe3od                43
# 4  spotify:track:2Y93hToFlR6CBItrUqsGqG                40
#
#                added_at                   album_name                album_id  \
# 0  2015-09-16T22:33:32Z    Graceland (2011 Remaster)  4O7d2vnCa5sfyZph6gU4sa
# 1  2015-09-16T22:33:32Z  It Could Just Be This Place  14M1Is6t3MOkxjBynarKce
# 2  2015-09-16T22:33:32Z      Everything All The Time  5uMfshtC2Jwqui0NUyUYIL
# 3  2015-09-16T22:33:32Z                  Open Season  3vyA5G1a5ISREXX0A4D2Iv
# 4  2015-09-16T22:33:32Z                White Lighter  4cPNeJTCwhYoJJ8sfqLOCB
#
#                               album_uri      artist_name  \
# 0  spotify:album:4O7d2vnCa5sfyZph6gU4sa       Paul Simon
# 1  spotify:album:14M1Is6t3MOkxjBynarKce  not an Airplane
# 2  spotify:album:5uMfshtC2Jwqui0NUyUYIL   Band of Horses
# 3  spotify:album:3vyA5G1a5ISREXX0A4D2Iv       High Highs
# 4  spotify:album:4cPNeJTCwhYoJJ8sfqLOCB          Typhoon
#
#                 artist_id    ...       energy instrumentalness  key  liveness  \
# 0  2CvCyf1gEVhI0mX6aFXmVI    ...     0.690819     4.685153e-04    1  0.079664
# 1  2eTQ0GfNG2zrAghLUKkSas    ...          NaN              NaN  NaN       NaN
# 2  0OdUWJ0sBjDrqHygGUXeCF    ...     0.768954     7.311096e-08    0  0.092790
# 3  1cXVTtkpqSXVhyD32f9MS4    ...          NaN              NaN  NaN       NaN
# 4  6p6WlxIkeWH8yOYvciFfVl    ...     0.536411     2.085726e-01    2  0.357705
#
#   loudness  mode  speechiness    tempo  time_signature   valence
# 0   -9.653     0     0.033910  117.932               4  0.868158
# 1      NaN   NaN          NaN      NaN             NaN       NaN
# 2   -5.283     0     0.042186  122.507               4  0.111796
# 3      NaN   NaN          NaN      NaN             NaN       NaN
# 4   -8.108     1     0.044852   89.811               4  0.358969
#
# [5 rows x 29 columns]

# %%
reload(playlist_data)
justlike = playlist_data.main(USERNAME, 'justlike')
justlike.head()
# Out:
# Setting up
# getting playlist tracks from spotify
# merge with artist info from echo nest
# 0
# 10
# 20
# merge with track info from echo nest
# 0
# error on uri spotify:track:5iKoarDSV0EA1JN10Bljr5 index= 5
# error on uri spotify:track:52PQErfILpXit6fODq43UL index= 8
# error on uri spotify:track:0lDoG5fQ9cmpvpenwR7Jln index= 9
# 10
# error on uri spotify:track:4g9MgFNA9Kb63JRwpuMtVB index= 13
# error on uri spotify:track:7AThm81bz0E8g7jaLzynPQ index= 14
# error on uri spotify:track:4I3YxhCTk88ClnlBbtDaK0 index= 16
# error on uri spotify:track:57mSiuAbNKodMxhysZlKbN index= 18
# 20
# error on uri spotify:track:71cUqXJ3h1r0Ees6YdENLU index= 24
# error on uri spotify:track:73cUDxWzUOtoLbJdeVvydw index= 26
# error on uri spotify:track:0HPCLfG38YNyay8Erznli1 index= 28
#                track_name                track_id  \
# 0  Weird Fishes / Arpeggi  3hyI2HLQxWPtoT8Or2e5Rk
# 1  Sleep The Clock Around  63rPrnI0X6gU3US3KxKL64
# 2                Penelope  7meVBPjEcIQ9RIST78kNcB
# 3                  Kaputt  0hvcIDobOkiw5Xq1SK3dbj
# 4     Tangible Intangible  1qBQw98D0JIXvEXtoRUd2Z
#
#                               track_uri  track_popularity  \
# 0  spotify:track:3hyI2HLQxWPtoT8Or2e5Rk                38
# 1  spotify:track:63rPrnI0X6gU3US3KxKL64                 4
# 2  spotify:track:7meVBPjEcIQ9RIST78kNcB                 5
# 3  spotify:track:0hvcIDobOkiw5Xq1SK3dbj                13
# 4  spotify:track:1qBQw98D0JIXvEXtoRUd2Z                48
#
#                added_at                   album_name                album_id  \
# 0  2015-09-17T16:26:46Z     Live from Beacon Theatre  4EswoYiuj1pBOMFO33lC39
# 1  2015-09-17T16:26:46Z  The Boy With The Arab Strap  3uhUPlgihiYPLc0Wuhy31V
# 2  2015-09-17T16:26:46Z             Blue Screen Life  0TNBqCtt1n1IE7N8cFDzXX
# 3  2015-09-17T16:26:46Z                       Kaputt  1clYDgHxfhzxWQJH0ieRpx
# 4  2015-09-17T16:26:46Z    Quartz (Extended Edition)  6demkOx0AElVCCqmItJ9hn
#
#                               album_uri        artist_name  \
# 0  spotify:album:4EswoYiuj1pBOMFO33lC39    Umphrey's McGee
# 1  spotify:album:3uhUPlgihiYPLc0Wuhy31V  Belle & Sebastian
# 2  spotify:album:0TNBqCtt1n1IE7N8cFDzXX            Pinback
# 3  spotify:album:1clYDgHxfhzxWQJH0ieRpx          Destroyer
# 4  spotify:album:6demkOx0AElVCCqmItJ9hn   Fly Golden Eagle
#
#                 artist_id    ...       energy instrumentalness  key  liveness  \
# 0  7mQilAy42MqNPqUFqK4Z0o    ...     0.622539         0.330460   11  0.612415
# 1  4I2BJf80C0skQpp1sQmA0h    ...          NaN              NaN  NaN       NaN
# 2  4ZWvN9FEfdTea1SEHjpTNi    ...     0.478389         0.757876    7  0.115946
# 3  22ojy4H4ZVpowC4lRRC8In    ...     0.717274         0.147508    4  0.175701
# 4  7r2alhL2KKfbhgGuqL9LGg    ...     0.709572         0.000585    2  0.144467
#
#   loudness  mode  speechiness    tempo  time_signature   valence
# 0  -10.003     0     0.036251  157.278               4  0.303008
# 1      NaN   NaN          NaN      NaN             NaN       NaN
# 2  -14.938     1     0.037901  117.896               4  0.520831
# 3   -8.944     1     0.034422  109.994               4  0.582023
# 4   -8.612     1     0.027993  104.069               4  0.594914
#
# [5 rows x 29 columns]

# %%
import seaborn as sns
pd.options.display.mpl_style = 'default'
relavent_columns = ['track_popularity','discovery','familiarity',
                   'hotttnesss','acousticness','danceability','duration',
                    'energy','instrumentalness','key','liveness',
                    'loudness', 'mode', 'speechiness','tempo','time_signature',
                    'valence']
fvs_data = favorites[relavent_columns]
for c in relavent_columns:  
    plt.figure()
    sns.boxplot(fvs_data[c])
plt.show()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(fvs_data, 0.2, figsize=(5,5), diagonal='hist')
plt.xticks([],rotation='vertical')
plt.yticks([],rotation='horizontal')
plt.show()

# %%
from pandas.tools.plotting import parallel_coordinates
parallel_coordinates

# %% [markdown]
# *  I want to do some visualization of songs that I've saved on spotify.  What attributes do I tend to dig? Is there anything with a really narrow variance?  To do this, I need to download my spotify playlists and do some exploration with histograms, bar graphs, etc.
#
# *  I'm going to start getting into linear regression and shit, possibly alongside the textbook.
